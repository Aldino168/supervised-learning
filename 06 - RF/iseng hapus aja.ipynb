# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/house_price.csv",index_col="ID")
df.head()
# Out:
#        crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# ID
# 1   0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2   0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 4   0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5   0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 7   0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
#
#      black  lstat  medv
# ID
# 1   396.90   4.98  24.0
# 2   396.90   9.14  21.6
# 4   394.63   2.94  33.4
# 5   396.90   5.33  36.2
# 7   395.60  12.43  22.9

# %%
df.loc[1, ["zn"]]
# Out:
# zn    18.0
# Name: 1, dtype: float64

# %%
df["meta"] = pd.concat([df.loc[1, ["zn"]], df.loc[1, ["indus"]]], axis=1)
# Out:
# C:\Users\Rahmat\anaconda3\envs\jcopml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\jcopml\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...
